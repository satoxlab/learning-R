# %% [markdown]
# slide 1

# %% [markdown]
# slide 2

# %% [markdown]
# slide 3

# %% [markdown]
# slide 4

# %%
load("./Statistics_at_Gifu_Univ_2013/why_we_need_statistics_examples.RData")

# スライドと少し図が違います。似ているのでコードを貼りました。

png("t-test_example.png", width=480*8, height=480*4, res=400)
par(mfrow=c(1,2))
plot(x=c(rep(1.2,10), rep(1.8,10)), y=c(a,b), xlim=c(1,2), xaxt="n", xlab="Treatment", ylab="Effect")
boxplot(x=cbind(a,b), xlab="Treatment", ylab="Effect")

# %%
library(png)
img4 <- readPNG("t-test_example.png")
grid::grid.raster(img4)
# Out:
# plot without title

# %% [markdown]
# slide 5

# %%
plot(x=c(rep(1.2,10), rep(1.8,10)), y=c(a,b), xlim=c(1,2), xaxt="n", xlab="Treatment", ylab="Effect")
# Out:
# plot without title

# %% [markdown]
# slide 6

# %%
library(png)
img4 <- readPNG("t-test_example.png")
grid::grid.raster(img4)
# Out:
# plot without title

# %% [markdown]
# slide 7

# %% [markdown]
# slide 8

# %%
load("./Statistics_at_Gifu_Univ_2013/why_we_need_statistics_examples.RData")

png("logistic_regression_example.png", width=480*8, height=480*4, res=400)
par(mfrow=c(1,2))
plot(x=dat[,2], y=dat[,4], xlab="Concentration of molecular X", ylab="Suvival")
plot(x=dat[,2], y=dat[,5], xlab="Concentration of molecular X", ylab="Probability of suvival")


pValue <- 1
x <- c()
y <- c()

while (pValue > 0.05){
	a <- sample(seq(5, 13, by=0.1), 10)
	b <- sample(seq(5, 13, by=0.1), 10)
	tTestResult <- t.test(a, b)
	pValue <- tTestResult$p.value
}

# %%
library(png)
img8 <- readPNG("logistic_regression_example.png")
grid::grid.raster(img8)
# Out:
# plot without title

# %% [markdown]
# slide 9

# %% [markdown]
# slide 10

# %% [markdown]
# slide 11

# %% [markdown]
# slide 12

# %% [markdown]
# slide 13

# %% [markdown]
# slide 14

# %% [markdown]
# slide 15

# %% [markdown]
# slide 16

# %% [markdown]
# slide 17

# %% [markdown]
# slide 18

# %% [markdown]
# slide 19

# %% [markdown]
# slide 20

# %% [markdown]
# slide 21

# %% [markdown]
# slide 22

# %% [markdown]
# slide 23

# %% [markdown]
# slide 24

# %% [markdown]
# slide 25

# %% [markdown]
# slide 26

# %% [markdown]
# slide 27

# %% [markdown]
# slide 28

# %%
groups <- c("cows", "sheep", "horses", 
            "elephants", "giraffes")
males <- sample(1:10, 5)
females <- sample(1:10, 5)

par(mar=c(0.5, 5, 0.5, 1))

plot.new()
plot.window(xlim=c(-10, 10), ylim=c(-1.5, 5.5))

ticks <- seq(-10, 10, 5)
y <- 1:5
h <- 0.2

lines(rep(0, 2), c(-1.5, 5.5), col="grey")
segments(-10, y, 10, y, lty="dotted")
rect(-males, y-h, 0, y+h, col="dark grey")
rect(0, y-h, females, y+h, col="light grey")
mtext(groups, at=y, adj=1, side=2, las=2)
par(cex.axis=0.5, mex=0.5)
axis(1, at=ticks, labels=abs(ticks), pos=0)

tw <- 1.5*strwidth("females")
rect(-tw, -1-h, 0, -1+h, col="dark grey")
rect(0, -1-h, tw, -1+h, col="light grey")
text(0, -1, "males", pos=2)
text(0, -1, "females", pos=4)

box("inner", col="grey")
# Out:
# plot without title

# %% [markdown]
# slide 29

# %% [markdown]
# slide 30

# %% [markdown]
# slide 31

# %% [markdown]
# slide 32

# %% [markdown]
# slide 33

# %% [markdown]
# slide 34

# %% [markdown]
# slide 35

# %% [markdown]
# slide 36

# %% [markdown]
# slide 37

# %% [markdown]
# slide 38

# %% [markdown]
# slide 39

# %% [markdown]
# slide 40

# %% [markdown]
# slide 41

# %% [markdown]
# slide 42

# %%
sampleData <- rnorm(10000, mean=0, sd=1)

hist(sampleData, breaks=100)

abline(v=0, col="green")

abline(v=mean(sample(sampleData)[3]), col="magenta")
# Out:
# Plot with title “Histogram of sampleData”

# %% [markdown]
# slide 43

# %%
sampleData <- rnorm(10000, mean=0, sd=1)

hist(sampleData, breaks=100, main="", xlab="Value")
abline(v=0, col="green", lwd=2)

sampled.mean <- function(population, x){
    abline(v=mean(sample(population,x)), 
           col="magenta",
           lwd=2
          )
}

sampled.mean(sampleData, 3)
for (i in 1:9) sampled.mean(sampleData, 3)
# Out:
# Plot with title “”

# %% [markdown]
# slide 44

# %% [markdown]
# slide 45

# %%
curve(dnorm(x, mean=0, sd=1), from=-4, to=4)     
abline(v=0, col="magenta")
# Out:
# plot without title

# %% [markdown]
# slide 46

# %% [markdown]
# slide 47

# %% [markdown]
# slide 48

# %%
sampleData <- rnorm(10000, mean=0, sd=1)

hist(sampleData, breaks=100, main="", xlab="Value")
abline(v=0, col="green", lwd=2)

sampled.mean <- function(population, x){
    abline(v=mean(sample(population,x)), 
           col="magenta",
           lwd=2
          )
}

sampled.mean(sampleData, 3)
for (i in 1:9) sampled.mean(sampleData, 3)
# Out:
# Plot with title “”

# %% [markdown]
# slide 49

# %% [markdown]
# slide 50

# %% [markdown]
# slide 51

# %% [markdown]
# slide 52

# %% [markdown]
# slide 53

# %% [markdown]
# slide 54

# %%
load("./Statistics_at_Gifu_Univ_2013/2012-07-26.RData")

png(filename="Lovett_histogram.png")
hist(as.matrix(dat), breaks=18, 
     xlab="Measured value",   
     main="An example of histogram",
     col="gray"
    )
dev.off()
# Out:
# pdf
#   2

# %%
library(png)
img54 <- readPNG("Lovett_histogram.png")
grid::grid.raster(img54)
# Out:
# plot without title

# %% [markdown]
# slide 55

# %% [markdown]
# slide 56

# %% [markdown]
# slide 57

# %% [markdown]
# slide 58

# %% [markdown]
# slide 59

# %% [markdown]
# slide 60

# %%
sampleData <- rnorm(10000, mean=0, sd=1)

hist(sampleData, breaks=100, main="", xlab="Value")
abline(v=0, col="green", lwd=2)

sampled.mean <- function(population, x){
    abline(v=mean(sample(population,x)), 
           col="magenta",
           lwd=2
          )
}

sampled.mean(sampleData, 3)
for (i in 1:9) sampled.mean(sampleData, 3)
# Out:
# Plot with title “”

# %% [markdown]
# slide 61

# %% [markdown]
# slide 62

# %% [markdown]
# slide 63

# %%
library(png)
img54 <- readPNG("Lovett_histogram.png")
grid::grid.raster(img54)
# Out:
# plot without title

# %% [markdown]
# slide 64

# %%
# gregmiscをインストールできませんでした。

library(gregmisc)
png(filename="Lovett_barplot.png")
barplot2(mean(dat[,1]), horiz=TRUE,
         plot.ci=TRUE, 
         ci.l=mean(dat[,1])-sd(dat[,1]), 
         ci.u=mean(dat[,1])+sd(dat[,1]), 
         xlim=c(10, 80)
        )
dev.off()
# Out:
# Error in library(gregmisc): there is no package called ‘gregmisc’
# Traceback:
#
# 1. library(gregmisc)

# %%
install.packages('gregmisc')
# Out:
# Warning message:
# “package ‘gregmisc’ is not available (for R version 3.6.1)”

# %% [markdown]
# slide 65

# %% [markdown]
# slide 66

# %%
load("./Statistics_at_Gifu_Univ_2013/why_we_need_statistics_examples.RData")

png(filename="Lovett_barplot.png")
boxplot(dat, 
        horizontal=TRUE, col="gray"
       )
dev.off()
# Out:
# pdf
#   2

# %%
library(png)
img66 <- readPNG("Lovett_barplot.png")
grid::grid.raster(img66)
# Out:
# plot without title

# %% [markdown]
# slide 67

# %% [markdown]
# slide 68

# %% [markdown]
# slide 69

# %% [markdown]
# slide 70

# %%
load("./Statistics_at_Gifu_Univ_2013/why_we_need_statistics_examples.RData")
load("./Statistics_at_Gifu_Univ_2013/2012-07-26.RData")

png("Lovette_log_transformation.png",  
    width=480*1.5
   )
par(mfrow=c(1,2))
hist(as.matrix(dat), breaks=18, 
     xlab="Measured value", 
     main="Raw data", col="gray", 
     prob=TRUE
    )
lines(density(as.matrix(dat)))

hist(as.matrix(log10(dat)), breaks=18, 
     xlab="Log10-transformed Measured value", 
     main="Log10 transformation", 
     col="gray", prob=TRUE
    )
lines(density(as.matrix(log10(dat))))
dev.off()
# Out:
# pdf
#   2

# %%
library(png)
img70 <- readPNG("Lovette_log_transformation.png")
grid::grid.raster(img70)
# Out:
# plot without title

# %% [markdown]
# slide 71

# %% [markdown]
# slide 72

# %% [markdown]
# slide 73

# %% [markdown]
# slide 74

# %% [markdown]
# slide 75

# %% [markdown]
# slide 76

# %% [markdown]
# slide 77

# %% [markdown]
# slide 78

# %%
png("normal_distribution1000.png")
x <-rnorm(1000)
hist(x, freq =FALSE, col ="grey", main="", xlab="value")
curve(dnorm, col = 2, add =TRUE)
abline(v=mean(x))
abline(v=mean(x), col="magenta", lty=2)
abline(v=mean(x)+sd(x), col="green", lty=2)
abline(v=mean(x)-sd(x), col="green", lty=2)
abline(v=mean(x)+2*sd(x), col="dark green", lty=2)
abline(v=mean(x)-2*sd(x), col="dark green", lty=2)
abline(v=mean(x)+3*sd(x), col="black", lty=2)
abline(v=mean(x)-3*sd(x), col="black", lty=2)
dev.off()
# Out:
# pdf
#   2

# %%
library(png)
img78 <- readPNG("normal_distribution1000.png")
grid::grid.raster(img78)
# Out:
# plot without title

# %% [markdown]
# slide 79

# %% [markdown]
# slide 80

# %% [markdown]
# slide 81

# %% [markdown]
# slide 82

# %%
load("./Statistics_at_Gifu_Univ_2013/2012-07-26.RData")

hist(as.matrix(dat), breaks=18, 
     xlab="Measured value",   
     main="An example of histogram",
     col="gray"
    )
# Out:
# Plot with title “An example of histogram”

# %% [markdown]
# slide 83

# %% [markdown]
# slide 84

# %% [markdown]
# slide 85

# %%
library(png)
img78 <- readPNG("normal_distribution1000.png")
grid::grid.raster(img78)
# Out:
# plot without title

# %% [markdown]
# slide 86
