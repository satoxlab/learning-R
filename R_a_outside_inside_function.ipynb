# %% [markdown]
# 変数`a`への代入と関数`a_function`内での`a`への代入を行い、それらの関係を確認しましょう。

# %%
a <- 3
a

# %%
a <- 5
a

# %%
a_function <- function(x){
  a <- x + 1
  return(a)
}

# %% [markdown]
# では、`a_function()`を実行してみます。

# %%
a_function(1)

# %% [markdown]
# `a_function(1)`を実行することにより、入力した１に1を加え、`a`に代入した結果を得ました。計算結果は2でした。
#
# ここで再度、`a`の内容を確認しましょう。

# %%
a
